# %%
# %matplotlib inline 
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers, Sequential, Model
from tensorflow.keras.layers import Dense, Conv3D, Conv1D, Conv3DTranspose, Dropout, MaxPool3D, Flatten, Reshape, Input, Permute, GlobalAvgPool3D
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.optimizers import Adam, SGD
import numpy as np
from random import sample, seed
from tqdm import tqdm
import matplotlib.pyplot as plt

class AAE():
    #Adversarial Autoencoder
    def __init__(self, img_shape=(48, 96, 96, 1), encoded_dim=16, optimizer_generator = SGD(0.01, momentum=.9), 
                optimizer_discriminator = SGD(0.001, momentum=.9), optimizer_autoencoder = Adam(0.001)):
        self.encoded_dim = encoded_dim
        self.optimizer_generator = optimizer_generator
        self.optimizer_discriminator = optimizer_discriminator
        self.optimizer_autoencoder = optimizer_autoencoder
        self.img_shape = img_shape
        self.initializer = RandomNormal(mean=0., stddev=1.)
        self.encoder, self.decoder, self.autoencoder, self.discriminator, \
                self.discriminator2, self.generator, self.generator2 = self._modelCompile(
                self.img_shape, self.encoded_dim, \
                self.optimizer_autoencoder,\
                self.optimizer_discriminator,\
                self.optimizer_generator
                )

    def _buildEncoder(self, img_shape, encoded_dim):

        encoder = Sequential()
        encoder.add(Conv3D(input_shape = img_shape, filters = 16, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #encoder.add(Dropout(0.2))
        encoder.add(Conv3D(filters = 16, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        #encoder.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))
        
        encoder.add(Conv3D(filters = 32, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #encoder.add(Dropout(0.2))
        encoder.add(Conv3D(filters = 32, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        #encoder.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))
        
        encoder.add(Conv3D(filters = 64, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #encoder.add(Dropout(0.2))
        encoder.add(Conv3D(filters = 64, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        #encoder.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))

        encoder.add(Conv3D(filters = 128, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #encoder.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))
        #encoder.add(GlobalAvgPool3D())
        encoder.add(Conv3D(filters = 1, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        encoder.add(Flatten())
        encoder.add(Dense(512, activation="relu"))
        encoder.add(Dense(512, activation="relu"))
        encoder.add(Dense(encoded_dim))
        
        return encoder

    def _buildDecoder(self, encoded_dim):

        decoder = Sequential()
        decoder.add(Dense(256, activation='relu', input_dim=encoded_dim))
        decoder.add(Dense(256, activation='relu'))
        decoder.add(Dense(3*6*6*128, activation='relu'))
        #decoder.add(Reshape([12*24*24,1]))
        #decoder.add(Conv1D(filters = 64, kernel_size=1, padding='SAME', activation='relu'))
        #decoder.add(Permute((2,1)))
        decoder.add(Reshape([3,6,6,128]))
        decoder.add(Conv3DTranspose(filters=64, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        decoder.add(Conv3DTranspose(filters=64, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        decoder.add(Conv3DTranspose(filters=32, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        decoder.add(Conv3DTranspose(filters=32, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        decoder.add(Conv3DTranspose(filters=16, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        decoder.add(Conv3DTranspose(filters=16, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        decoder.add(Conv3DTranspose(filters=1, kernel_size=3, strides=(2,)*3, padding="SAME", activation='relu'))
        
        return decoder

    def _buildDiscriminator(self, encoded_dim):

        discriminator = Sequential()
        discriminator.add(Dense(1024, input_dim=encoded_dim, activation="relu"))
        discriminator.add(Dense(1024, activation="relu"))
        discriminator.add(Dense(128, activation="relu"))
        discriminator.add(Dense(1, activation="sigmoid"))

        return discriminator
    
    def _buildDiscriminator2(self, img_shape):
        
        discriminator = Sequential()
        discriminator.add(Conv3D(input_shape = img_shape, filters = 16, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #discriminator.add(Dropout(0.2))
        #discriminator.add(Conv3D(filters = 16, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        discriminator.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))
        
        #discriminator.add(Conv3D(filters = 32, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #discriminator.add(Dropout(0.2))
        discriminator.add(Conv3D(filters = 32, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        discriminator.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))
        
        #discriminator.add(Conv3D(filters = 64, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #discriminator.add(Dropout(0.2))
        discriminator.add(Conv3D(filters = 64, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        discriminator.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))

        discriminator.add(Conv3D(filters = 128, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        #discriminator.add(MaxPool3D(pool_size=(2,)*3, padding="SAME"))
        discriminator.add(GlobalAvgPool3D())
        #discriminator.add(Conv3D(filters = 1, kernel_size=3, strides=(1,)*3, padding="SAME", activation='relu'))
        discriminator.add(Flatten())
        discriminator.add(Dense(128, activation="relu"))
        discriminator.add(Dense(1, activation="sigmoid"))
        
        return discriminator

    def _modelCompile(self, img_shape, encoded_dim, optimizer_autoencoder, optimizer_discriminator, optimizer_generator):

        encoder=self._buildEncoder(img_shape, encoded_dim)
        decoder=self._buildDecoder(encoded_dim)
        
        autoencoder_input = Input(shape = img_shape) # this is the input for autoencoder and main generator
        decoder_input=Input(shape=encoded_dim)
        
        autoencoder=Model(autoencoder_input, decoder(encoder(autoencoder_input)))
        autoencoder.compile(optimizer=optimizer_autoencoder, loss="mse")

        discriminator=self._buildDiscriminator(encoded_dim)
        discriminator.trainable = False
        generator = Model(autoencoder_input, discriminator(encoder(autoencoder_input)))
        generator.compile(optimizer=optimizer_generator, loss="binary_crossentropy")
        discriminator.trainable = True
        discriminator.compile(optimizer=optimizer_discriminator, loss="binary_crossentropy")
    
        discriminator2 = self._buildDiscriminator2(img_shape)
        discriminator2.trainable = False
        generator2=Model(decoder_input, discriminator2(decoder(decoder_input)))
        generator2.compile(optimizer=optimizer_generator, loss="binary_crossentropy")
        discriminator2.trainable = True
        discriminator2.compile(optimizer=optimizer_discriminator, loss="binary_crossentropy")
        
        return encoder, decoder, autoencoder, discriminator, discriminator2, generator, generator2

    def train(self, train_set, batch_size, n_epochs, n_sample):

        autoencoder_losses = []
        discriminator_losses = []
        discriminator2_losses = []
        generator_losses = []
        generator2_losses = []

        for epoch in np.arange(1, n_epochs):
            x_idx_list = sample(range(n_sample), batch_size)
            x = train_set[x_idx_list]

            autoencoder_history = self.autoencoder.train_on_batch(x,x)
            fake_latent = self.encoder.predict(x)
            fake_image = self.decoder.predict(fake_latent)
            
            discriminator_input = np.concatenate((fake_latent, np.random.randn(batch_size, self.encoded_dim)))
            discriminator_labels = np.concatenate((np.zeros((batch_size, 1)), np.ones((batch_size, 1))))
            
            discriminator2_input = np.concatenate((fake_image, x))
            discriminator2_labels = np.concatenate((np.zeros((batch_size, 1)), np.ones((batch_size, 1))))
            
            discriminator_history = self.discriminator.train_on_batch(discriminator_input, discriminator_labels)
            generator_history = self.generator.train_on_batch(x, np.ones((batch_size, 1)))
            
            discriminator2_history = self.discriminator2.train_on_batch(discriminator2_input, discriminator2_labels)
            generator2_history = self.generator2.train_on_batch(fake_latent, np.ones((batch_size, 1)))
            
            autoencoder_losses.append(autoencoder_history)
            discriminator_losses.append(discriminator_history)
            discriminator2_losses.append(discriminator2_history)
            generator_losses.append(generator_history)
            generator2_losses.append(generator2_history)

            if epoch % 50 == 0:
                self.autoencoder.save("../GAN_log/autoencoder_epoch_{}.h5".format(epoch))
                #self.discriminator.save("../GAN_log/discriminator_epoch_{}.h5".format(epoch))
            print("Epoch--{}".format(epoch))
            print("AE_loss: {:.4f}  D1_loss:{:.3f}   D2_loss:{:.3f}   G1_loss:{:.3f}   G2_loss:{:.3f}".format(
                autoencoder_history, discriminator_history, discriminator2_history, generator_history, generator2_history
                )
            )

        self.history = {
                        'AE_loss':autoencoder_losses, 
                        'D1_loss':discriminator_losses, 
                        'D2_loss':discriminator_losses, 
                        'G1_loss':generator_losses,
                        'G2_loss':generator_losses
                       }
        
        return self.history

    def load_model(self):

        return

    def encodeImage(self):

        return 

    def plot_losses(self):

        return

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
# Invalid device or cannot modify virtual devices once initialized.
    pass

model = AAE(encoded_dim=128)

import os
import SimpleITK as sitk 

datapath = r'../100x100x48 niis'
file_reference = r'../File_reference.csv'

img_ls = os.listdir(datapath)
train_set = np.zeros(shape=[len(img_ls), 48, 96, 96, 1])

idx = 0
for file in tqdm(img_ls):
    img = sitk.ReadImage(os.path.join(datapath, file))
    img = sitk.GetArrayFromImage(img)
    img = img[:,2:98,2:98,np.newaxis].astype(np.float32) / 255.
    train_set[idx] = img
    idx += 1

batch_size=8
n_epochs=1000
seed=42
np.random.seed(42)

history = model.train(train_set, batch_size, n_epochs, len(img_ls))
# Out:
# 100%|██████████| 1198/1198 [00:07<00:00, 154.08it/s]
# Epoch--1
# AE_loss: 0.0316  D1_loss:0.674   D2_loss:0.701   G1_loss:0.693   G2_loss:0.693
# Epoch--2
# AE_loss: 0.0299  D1_loss:0.696   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--3
# AE_loss: 0.0263  D1_loss:0.676   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--4
# AE_loss: 0.0283  D1_loss:0.685   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--5
# AE_loss: 0.0262  D1_loss:0.662   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--6
# AE_loss: 0.0301  D1_loss:0.665   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--7
# AE_loss: 0.0299  D1_loss:0.681   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--8
# AE_loss: 0.0328  D1_loss:0.653   D2_loss:0.701   G1_loss:0.693   G2_loss:0.693
# Epoch--9
# AE_loss: 0.0297  D1_loss:0.684   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--10
# AE_loss: 0.0258  D1_loss:0.665   D2_loss:0.700   G1_loss:0.693   G2_loss:0.693
# Epoch--11
# AE_loss: 0.0335  D1_loss:0.667   D2_loss:0.701   G1_loss:0.692   G2_loss:0.693
# Epoch--12
# AE_loss: 0.0278  D1_loss:0.632   D2_loss:0.700   G1_loss:0.692   G2_loss:0.693
# Epoch--13
# AE_loss: 0.0290  D1_loss:0.668   D2_loss:0.699   G1_loss:0.692   G2_loss:0.693
# Epoch--14
# AE_loss: 0.0334  D1_loss:0.651   D2_loss:0.700   G1_loss:0.692   G2_loss:0.693
# Epoch--15
# AE_loss: 0.0268  D1_loss:0.632   D2_loss:0.700   G1_loss:0.692   G2_loss:0.693
# Epoch--16
# AE_loss: 0.0271  D1_loss:0.649   D2_loss:0.700   G1_loss:0.692   G2_loss:0.693
# Epoch--17
# AE_loss: 0.0233  D1_loss:0.651   D2_loss:0.699   G1_loss:0.692   G2_loss:0.693
# Epoch--18
# AE_loss: 0.0238  D1_loss:0.648   D2_loss:0.699   G1_loss:0.692   G2_loss:0.693
# Epoch--19
# AE_loss: 0.0331  D1_loss:0.658   D2_loss:0.700   G1_loss:0.692   G2_loss:0.693
# Epoch--20
# AE_loss: 0.0280  D1_loss:0.658   D2_loss:0.699   G1_loss:0.691   G2_loss:0.693
# Epoch--21
# AE_loss: 0.0316  D1_loss:0.641   D2_loss:0.700   G1_loss:0.691   G2_loss:0.693
# Epoch--22
# AE_loss: 0.0222  D1_loss:1.135   D2_loss:0.691   G1_loss:0.695   G2_loss:0.698
# Epoch--223
# AE_loss: 0.0232  D1_loss:1.093   D2_loss:0.691   G1_loss:0.695   G2_loss:0.698
# Epoch--224
# AE_loss: 0.0251  D1_loss:1.058   D2_loss:0.691   G1_loss:0.695   G2_loss:0.698
# Epoch--225
# AE_loss: 0.0258  D1_loss:1.019   D2_loss:0.691   G1_loss:0.695   G2_loss:0.698
# Epoch--226
# AE_loss: 0.0225  D1_loss:1.052   D2_loss:0.691   G1_loss:0.695   G2_loss:0.698
# Epoch--227
# AE_loss: 0.0247  D1_loss:1.047   D2_loss:0.691   G1_loss:0.694   G2_loss:0.698
# Epoch--228
# AE_loss: 0.0225  D1_loss:1.015   D2_loss:0.691   G1_loss:0.694   G2_loss:0.698
# Epoch--229
# AE_loss: 0.0250  D1_loss:1.064   D2_loss:0.691   G1_loss:0.694   G2_loss:0.698
# Epoch--230
# AE_loss: 0.0252  D1_loss:1.011   D2_loss:0.691   G1_loss:0.694   G2_loss:0.698
# Epoch--231
# AE_loss: 0.0223  D1_loss:1.068   D2_loss:0.691   G1_loss:0.693   G2_loss:0.698
# Epoch--232
# AE_loss: 0.0210  D1_loss:1.035   D2_loss:0.691   G1_loss:0.693   G2_loss:0.698
# Epoch--233
# AE_loss: 0.0237  D1_loss:1.033   D2_loss:0.691   G1_loss:0.693   G2_loss:0.698
# Epoch--234
# AE_loss: 0.0227  D1_loss:1.028   D2_loss:0.691   G1_loss:0.692   G2_loss:0.698
# Epoch--235
# AE_loss: 0.0199  D1_loss:0.977   D2_loss:0.691   G1_loss:0.692   G2_loss:0.698
# Epoch--236
# AE_loss: 0.0222  D1_loss:1.005   D2_loss:0.691   G1_loss:0.692   G2_loss:0.698
# Epoch--237
# AE_loss: 0.0225  D1_loss:1.044   D2_loss:0.691   G1_loss:0.692   G2_loss:0.698
# Epoch--238
# AE_loss: 0.0206  D1_loss:1.040   D2_loss:0.691   G1_loss:0.691   G2_loss:0.698
# Epoch--239
# AE_loss: 0.0231  D1_loss:0.968   D2_loss:0.691   G1_loss:0.691   G2_loss:0.698
# Epoch--240
# AE_loss: 0.0208  D1_loss:1.037   D2_loss:0.691   G1_loss:0.691   G2_loss:0.698
# Epoch--241
# AE_loss: 0.0252  D1_loss:0.995   D2_loss:0.691   G1_loss:0.691   G2_loss:0.698
# Epoch--242
# AE_loss: 0.0218  D1_loss:1.008   D2_loss:0.691   G1_loss:0.691   G2_loss:0.698
# Epoch--243
# AE_loss: 0.0218  D1_loss:1.011   D2_loss:0.691   G1_loss:0.690   G2_loss:0.698
# Epoch--244
# AE_loss: 0.0229  D1_loss:1.033   D2_loss:0.691   G1_loss:0.690   G2_loss:0.698
# Epoch--245
# AE_loss: 0.0230  D1_loss:1.002   D2_loss:0.691   G1_loss:0.690   G2_loss:0.698
# Epoch--246
# AE_loss: 0.0224  D1_loss:1.009   D2_loss:0.691   G1_loss:0.690   G2_loss:0.698
# Epoch--247
# AE_loss: 0.0222  D1_loss:0.874   D2_loss:0.691   G1_loss:0.684   G2_loss:0.698
# Epoch--273
# AE_loss: 0.0205  D1_loss:0.847   D2_loss:0.691   G1_loss:0.684   G2_loss:0.698
# Epoch--274
# AE_loss: 0.0211  D1_loss:0.877   D2_loss:0.691   G1_loss:0.684   G2_loss:0.698
# Epoch--275
# AE_loss: 0.0209  D1_loss:0.886   D2_loss:0.691   G1_loss:0.683   G2_loss:0.698
# Epoch--276
# AE_loss: 0.0229  D1_loss:0.817   D2_loss:0.691   G1_loss:0.683   G2_loss:0.698
# Epoch--277
# AE_loss: 0.0188  D1_loss:0.853   D2_loss:0.691   G1_loss:0.683   G2_loss:0.698
# Epoch--278
# AE_loss: 0.0210  D1_loss:0.877   D2_loss:0.691   G1_loss:0.683   G2_loss:0.698
# Epoch--279
# AE_loss: 0.0182  D1_loss:0.889   D2_loss:0.691   G1_loss:0.683   G2_loss:0.698
# Epoch--280
# AE_loss: 0.0221  D1_loss:0.882   D2_loss:0.691   G1_loss:0.682   G2_loss:0.698
# Epoch--281
# AE_loss: 0.0233  D1_loss:0.858   D2_loss:0.691   G1_loss:0.682   G2_loss:0.698
# Epoch--282
# AE_loss: 0.0220  D1_loss:0.897   D2_loss:0.691   G1_loss:0.682   G2_loss:0.698
# Epoch--283
# AE_loss: 0.0186  D1_loss:0.825   D2_loss:0.691   G1_loss:0.682   G2_loss:0.698
# Epoch--284
# AE_loss: 0.0209  D1_loss:0.829   D2_loss:0.691   G1_loss:0.682   G2_loss:0.698
# Epoch--285
# AE_loss: 0.0198  D1_loss:0.866   D2_loss:0.691   G1_loss:0.681   G2_loss:0.698
# Epoch--286
# AE_loss: 0.0221  D1_loss:0.846   D2_loss:0.691   G1_loss:0.681   G2_loss:0.698
# Epoch--287
# AE_loss: 0.0212  D1_loss:0.883   D2_loss:0.691   G1_loss:0.681   G2_loss:0.697
# Epoch--288
# AE_loss: 0.0210  D1_loss:0.855   D2_loss:0.691   G1_loss:0.681   G2_loss:0.697
# Epoch--289
# AE_loss: 0.0190  D1_loss:0.859   D2_loss:0.691   G1_loss:0.681   G2_loss:0.698
# Epoch--290
# AE_loss: 0.0222  D1_loss:0.803   D2_loss:0.691   G1_loss:0.681   G2_loss:0.698
# Epoch--291
# AE_loss: 0.0206  D1_loss:0.864   D2_loss:0.691   G1_loss:0.680   G2_loss:0.698
# Epoch--292
# AE_loss: 0.0208  D1_loss:0.784   D2_loss:0.691   G1_loss:0.680   G2_loss:0.698
# Epoch--293
# AE_loss: 0.0247  D1_loss:0.824   D2_loss:0.691   G1_loss:0.680   G2_loss:0.698
# Epoch--294
# AE_loss: 0.0186  D1_loss:0.838   D2_loss:0.691   G1_loss:0.680   G2_loss:0.698
# Epoch--295
# AE_loss: 0.0211  D1_loss:0.848   D2_loss:0.691   G1_loss:0.680   G2_loss:0.698
# Epoch--296
# AE_loss: 0.0177  D1_loss:0.832   D2_loss:0.691   G1_loss:0.679   G2_loss:0.698
# Epoch--297
# AE_loss: 0.0194  D1_loss:0.808   D2_loss:0.691   G1_loss:0.679   G2_loss:0.698
# Epoch--298
# AE_loss: 0.0213  D1_loss:0.866   D2_loss:0.691   G1_loss:0.679   G2_loss:0.698
# Epoch--299
# AE_loss: 0.0202  D1_loss:0.814   D2_loss:0.691   G1_loss:0.679   G2_loss:0.698
# Epoch--300
# AE_loss: 0.0193  D1_loss:0.814   D2_loss:0.691   G1_loss:0.678   G2_loss:0.698
# Epoch--301
# AE_loss: 0.0221  D1_loss:0.847   D2_loss:0.691   G1_loss:0.678   G2_loss:0.698
# Epoch--302
# AE_loss: 0.0183  D1_loss:0.758   D2_loss:0.691   G1_loss:0.678   G2_loss:0.698
# Epoch--303
# AE_loss: 0.0229  D1_loss:0.796   D2_loss:0.691   G1_loss:0.678   G2_loss:0.697
# Epoch--304
# AE_loss: 0.0183  D1_loss:0.788   D2_loss:0.691   G1_loss:0.678   G2_loss:0.697
# Epoch--305
# AE_loss: 0.0197  D1_loss:0.782   D2_loss:0.691   G1_loss:0.677   G2_loss:0.698
# Epoch--306
# AE_loss: 0.0193  D1_loss:0.832   D2_loss:0.691   G1_loss:0.677   G2_loss:0.698
# Epoch--307
# AE_loss: 0.0208  D1_loss:0.787   D2_loss:0.691   G1_loss:0.677   G2_loss:0.698
# Epoch--308
# AE_loss: 0.0204  D1_loss:0.765   D2_loss:0.691   G1_loss:0.677   G2_loss:0.698
# Epoch--309
# AE_loss: 0.0201  D1_loss:0.807   D2_loss:0.691   G1_loss:0.677   G2_loss:0.698
# Epoch--310
# AE_loss: 0.0213  D1_loss:0.795   D2_loss:0.691   G1_loss:0.676   G2_loss:0.698
# Epoch--311
# AE_loss: 0.0194  D1_loss:0.822   D2_loss:0.691   G1_loss:0.676   G2_loss:0.698
# Epoch--312
# AE_loss: 0.0186  D1_loss:0.790   D2_loss:0.691   G1_loss:0.676   G2_loss:0.697
# Epoch--313
# AE_loss: 0.0186  D1_loss:0.770   D2_loss:0.691   G1_loss:0.676   G2_loss:0.698
# Epoch--314
# AE_loss: 0.0209  D1_loss:0.779   D2_loss:0.691   G1_loss:0.675   G2_loss:0.698
# Epoch--315
# AE_loss: 0.0210  D1_loss:0.817   D2_loss:0.691   G1_loss:0.675   G2_loss:0.698
# Epoch--316
# AE_loss: 0.0219  D1_loss:0.815   D2_loss:0.691   G1_loss:0.675   G2_loss:0.698
# Epoch--317
# AE_loss: 0.0195  D1_loss:0.768   D2_loss:0.691   G1_loss:0.675   G2_loss:0.698
# Epoch--318
# AE_loss: 0.0225  D1_loss:0.774   D2_loss:0.691   G1_loss:0.675   G2_loss:0.698
# Epoch--319
# AE_loss: 0.0184  D1_loss:0.761   D2_loss:0.691   G1_loss:0.674   G2_loss:0.698
# Epoch--320
# AE_loss: 0.0165  D1_loss:0.725   D2_loss:0.691   G1_loss:0.674   G2_loss:0.698
# Epoch--321
# AE_loss: 0.0158  D1_loss:0.787   D2_loss:0.691   G1_loss:0.674   G2_loss:0.698
# AE_loss: 0.0175  D1_loss:0.445   D2_loss:0.687   G1_loss:0.704   G2_loss:0.700
# Epoch--986
# AE_loss: 0.0185  D1_loss:0.445   D2_loss:0.687   G1_loss:0.703   G2_loss:0.700
# Epoch--987
# AE_loss: 0.0184  D1_loss:0.453   D2_loss:0.687   G1_loss:0.703   G2_loss:0.700
# Epoch--988
# AE_loss: 0.0227  D1_loss:0.427   D2_loss:0.686   G1_loss:0.703   G2_loss:0.700
# Epoch--989
# AE_loss: 0.0190  D1_loss:0.440   D2_loss:0.686   G1_loss:0.703   G2_loss:0.700
# Epoch--990
# AE_loss: 0.0198  D1_loss:0.453   D2_loss:0.687   G1_loss:0.703   G2_loss:0.700
# Epoch--991
# AE_loss: 0.0197  D1_loss:0.451   D2_loss:0.687   G1_loss:0.703   G2_loss:0.700
# Epoch--992
# AE_loss: 0.0192  D1_loss:0.436   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--993
# AE_loss: 0.0195  D1_loss:0.446   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--994
# AE_loss: 0.0186  D1_loss:0.438   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--995
# AE_loss: 0.0172  D1_loss:0.441   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--996
# AE_loss: 0.0184  D1_loss:0.444   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--997
# AE_loss: 0.0191  D1_loss:0.436   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--998
# AE_loss: 0.0179  D1_loss:0.437   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699
# Epoch--999
# AE_loss: 0.0183  D1_loss:0.445   D2_loss:0.687   G1_loss:0.703   G2_loss:0.699

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 3, figsize=(16,9))

ax[0, 0].plot(range(n_epochs-1), history["AE_loss"], label="AE_loss")
ax[0, 0].set_title("AE_loss")

ax[0, 1].plot(range(n_epochs-1), history["G1_loss"], label="G1_loss")
ax[0, 1].set_title("G1_loss")

ax[0, 2].plot(range(n_epochs-1), history["D1_loss"], label="D1_loss")
ax[0, 2].set_title("D1_loss")

ax[1, 0].plot(range(n_epochs-1), history["G2_loss"], label="G2_loss")
ax[1, 0].set_title("G2_loss")

ax[1, 1].plot(range(n_epochs-1), history["D2_loss"], label="D2_loss")
ax[1, 1].set_title("D2_loss")

plt.show()

# %%
image = train_set[0].reshape((1,48,96,96,1))
gen_image=np.squeeze(model.autoencoder.predict(image))
image = np.squeeze(image)

# %%
fig2, ax = plt.subplots(3,2, figsize=(8,9))
ax[0,0].imshow(image[35,:,:])
ax[0,1].imshow(gen_image[35,:,:])
ax[1,0].imshow(image[::-1,50,:])
ax[1,1].imshow(gen_image[::-1,50,:])
ax[2,0].imshow(image[::-1,:,60])
ax[2,1].imshow(gen_image[::-1,:,60])

# %%
model = AAE(encoded_dim=256)
model.encoder.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_24 (Conv3D)           (None, 48, 96, 96, 16)    448
# _________________________________________________________________
# conv3d_25 (Conv3D)           (None, 24, 48, 48, 16)    6928
# _________________________________________________________________
# conv3d_26 (Conv3D)           (None, 24, 48, 48, 32)    13856
# _________________________________________________________________
# conv3d_27 (Conv3D)           (None, 12, 24, 24, 32)    27680
# _________________________________________________________________
# conv3d_28 (Conv3D)           (None, 12, 24, 24, 64)    55360
# _________________________________________________________________
# conv3d_29 (Conv3D)           (None, 6, 12, 12, 64)     110656
# _________________________________________________________________
# conv3d_30 (Conv3D)           (None, 6, 12, 12, 128)    221312
# _________________________________________________________________
# conv3d_31 (Conv3D)           (None, 6, 12, 12, 1)      3457
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 864)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 512)               442880
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_26 (Dense)             (None, 256)               131328
# =================================================================
# Total params: 1,276,561
# Trainable params: 1,276,561
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.decoder.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_22 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_23 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_24 (Dense)             (None, 13824)             3552768
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 3, 6, 6, 128)      0
# _________________________________________________________________
# conv3d_transpose_14 (Conv3DT (None, 6, 12, 12, 64)     221248
# _________________________________________________________________
# conv3d_transpose_15 (Conv3DT (None, 6, 12, 12, 64)     110656
# _________________________________________________________________
# conv3d_transpose_16 (Conv3DT (None, 12, 24, 24, 32)    55328
# _________________________________________________________________
# conv3d_transpose_17 (Conv3DT (None, 12, 24, 24, 32)    27680
# _________________________________________________________________
# conv3d_transpose_18 (Conv3DT (None, 24, 48, 48, 16)    13840
# _________________________________________________________________
# conv3d_transpose_19 (Conv3DT (None, 24, 48, 48, 16)    6928
# _________________________________________________________________
# conv3d_transpose_20 (Conv3DT (None, 48, 96, 96, 1)     433
# =================================================================
# Total params: 4,120,465
# Trainable params: 4,120,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.discriminator2.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_103 (Conv3D)          (None, 48, 96, 96, 16)    448
# _________________________________________________________________
# conv3d_104 (Conv3D)          (None, 48, 96, 96, 16)    6928
# _________________________________________________________________
# max_pooling3d_43 (MaxPooling (None, 24, 48, 48, 16)    0
# _________________________________________________________________
# conv3d_105 (Conv3D)          (None, 24, 48, 48, 32)    13856
# _________________________________________________________________
# conv3d_106 (Conv3D)          (None, 24, 48, 48, 32)    27680
# _________________________________________________________________
# max_pooling3d_44 (MaxPooling (None, 12, 24, 24, 32)    0
# _________________________________________________________________
# conv3d_107 (Conv3D)          (None, 12, 24, 24, 64)    55360
# _________________________________________________________________
# conv3d_108 (Conv3D)          (None, 12, 24, 24, 64)    110656
# _________________________________________________________________
# max_pooling3d_45 (MaxPooling (None, 6, 12, 12, 64)     0
# _________________________________________________________________
# conv3d_109 (Conv3D)          (None, 6, 12, 12, 128)    221312
# _________________________________________________________________
# global_average_pooling3d_7 ( (None, 128)               0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_85 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 436,369
# Trainable params: 436,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.generator.layers:
    print(layer.trainable)
# Out:
# True
# True
# True

# %%
model.generator2.summary()
# Out:
# Model: "model_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        [(None, 128)]             0
# _________________________________________________________________
# sequential_50 (Sequential)   (None, 48, 96, 96, 1)     2219409
# _________________________________________________________________
# sequential_52 (Sequential)   (None, 1)                 69729
# =================================================================
# Total params: 2,219,409
# Trainable params: 2,219,409
# Non-trainable params: 0
# _________________________________________________________________
